# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
color = sns.color_palette()

# %%
df = pd.read_csv("echocardiogram.csv")
df.head()
# Out:
#    survival  alive   age  pericardialeffusion  fractionalshortening    epss  \
# 0      11.0    0.0  71.0                  0.0                 0.260   9.000
# 1      19.0    0.0  72.0                  0.0                 0.380   6.000
# 2      16.0    0.0  55.0                  0.0                 0.260   4.000
# 3      57.0    0.0  60.0                  0.0                 0.253  12.062
# 4      19.0    1.0  57.0                  0.0                 0.160  22.000
#
#     lvdd  wallmotion-score  wallmotion-index   mult  name group  aliveat1
# 0  4.600              14.0              1.00  1.000  name     1       0.0
# 1  4.100              14.0              1.70  0.588  name     1       0.0
# 2  3.420              14.0              1.00  1.000  name     1       0.0
# 3  4.603              16.0              1.45  0.788  name     1       0.0
# 4  5.750              18.0              2.25  0.571  name     1       0.0

# %%
df["aliveat1"].value_counts()
# Out:
# 0.0    50
# 1.0    24
# 2.0     1
# Name: aliveat1, dtype: int64

# %%
df["group"].value_counts()
# Out:
# 2       85
# 1       24
# name     1
# Name: group, dtype: int64

# %%
df.drop("name", axis=1, inplace=True)

# %%
df.drop("group", axis=1, inplace=True)

# %%
for col in df.columns:
   
    print(df[col].value_counts())
    print("***"*10)
# Out:
# 0.50     6
# 1.00     6
# 0.75     6
# 26.00    5
# 33.00    5
# 36.00    4
# 29.00    4
# 12.00    4
# 19.00    4
# 25.00    4
# 27.00    4
# 0.25     4
# 22.00    4
# 34.00    3
# 32.00    3
# 31.00    3
# 41.00    3
# 24.00    3
# 10.00    3
# 16.00    3
# 37.00    2
# 5.00     2
# 15.00    2
# 49.00    2
# 38.00    2
# 53.00    2
# 17.00    2
# 20.00    2
# 21.00    2
# 40.00    2
# 2.00     2
# 13.00    2
# 28.00    2
# 35.00    2
# 52.00    2
# 3.00     2
# 55.00    1
# 23.00    1
# 0.03     1
# 1.25     1
# 4.00     1
# 11.00    1
# 47.00    1
# 9.00     1
# 45.00    1
# 7.00     1
# 19.50    1
# 46.00    1
# 48.00    1
# 44.00    1
# 50.00    1
# 57.00    1
# 7.50     1
# Name: survival, dtype: int64
# ******************************
# 0.0    88
# 1.0    43
# Name: alive, dtype: int64
# ******************************
# 62.000    10
# 57.000     8
# 61.000     8
# 63.000     7
# 59.000     7
# 64.000     7
# 60.000     6
# 54.000     6
# 55.000     5
# 70.000     5
# ...

# %%
df.describe()
# Out:
#          survival       alive         age  pericardialeffusion  \
# count  130.000000  131.000000  126.000000           132.000000
# mean    22.182923    0.328244   62.813722             0.765152
# std     15.858267    0.471377    8.342110             6.697225
# min      0.030000    0.000000   35.000000             0.000000
# 25%      7.875000    0.000000   57.000000             0.000000
# 50%     23.500000    0.000000   62.000000             0.000000
# 75%     33.000000    1.000000   67.750000             0.000000
# max     57.000000    1.000000   86.000000            77.000000
#
#        fractionalshortening        epss        lvdd  wallmotion-score  \
# count            124.000000  117.000000  121.000000        128.000000
# mean               0.216734   12.164769    4.763157         14.438125
# std                0.107513    7.370159    0.810013          5.018566
# min                0.010000    0.000000    2.320000          2.000000
# ...

# %%
df.corr()
# Out:
#                       survival     alive       age  pericardialeffusion  \
# survival              1.000000 -0.711073 -0.207691            -0.153606
# alive                -0.711073  1.000000  0.295950             0.173229
# age                  -0.207691  0.295950  1.000000             0.014594
# pericardialeffusion  -0.153606  0.173229  0.014594             1.000000
# fractionalshortening  0.241328 -0.294011 -0.083279            -0.009492
# epss                 -0.295099  0.330701  0.045540             0.073149
# lvdd                 -0.230969  0.264787  0.173159             0.063501
# wallmotion-score     -0.292460  0.272232  0.035560             0.143504
# wallmotion-index     -0.354789  0.386709  0.050617             0.123202
# mult                  0.064442 -0.139697 -0.159578             0.474249
# aliveat1             -0.758264  0.863034  0.254399             0.391019
#
#                       fractionalshortening      epss      lvdd  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   survival              130 non-null    float64
#  1   alive                 131 non-null    float64
#  2   age                   126 non-null    float64
#  3   pericardialeffusion   132 non-null    float64
#  4   fractionalshortening  124 non-null    float64
#  5   epss                  117 non-null    float64
#  6   lvdd                  121 non-null    float64
#  7   wallmotion-score      128 non-null    float64
#  8   wallmotion-index      130 non-null    float64
#  9   mult                  129 non-null    float64
#  10  aliveat1              75 non-null     float64
# dtypes: float64(11)
# memory usage: 11.6 KB

# %%
df.isnull().sum()
# Out:
# survival                 3
# alive                    2
# age                      7
# pericardialeffusion      1
# fractionalshortening     9
# epss                    16
# lvdd                    12
# wallmotion-score         5
# wallmotion-index         3
# mult                     4
# aliveat1                58
# dtype: int64

# %%
mean = round(df["survival"].mean(), 2)

# %%
df["survival"].fillna(value=mean, inplace=True)

# %%
df["alive"].value_counts()
# Out:
# 0.0    88
# 1.0    43
# Name: alive, dtype: int64

# %%
maximal_wert=df["alive"].value_counts().max()

# %%
maximal_wert
# Out:
# 88

# %%
df["alive"].fillna(value=maximal_wert, inplace=True)
df["alive"].isnull().sum()
# Out:
# 0

# %%
round(df["age"].mean(),0)
# Out:
# 63.0

# %%
df["age"].fillna(value=round(df["age"].mean(),0)
                 , inplace=True)

# %%
df["age"] = df["age"].astype(int)

# %%
maximal_wert_per=df["pericardialeffusion"].value_counts().max()

# %%
df["pericardialeffusion"].fillna(value=maximal_wert, inplace=True)
df["pericardialeffusion"].isnull().sum()
# Out:
# 0

# %%
df["fractionalshortening"].fillna(
    value=round(
    df["fractionalshortening"].value_counts().mean(),
        3)
    ,inplace=True
)

# %%
df["fractionalshortening"].isnull().sum()
# Out:
# 0

# %%
round(df["epss"].mean(),3)
# Out:
# 12.165

# %%
df["epss"].fillna(
    value=round(
    df["epss"].value_counts().mean(),
        3)
    ,inplace=True
)

# %%
df["lvdd"].fillna(
    value=round(
    df["lvdd"].value_counts().mean(),
        3)
    ,inplace=True
)

# %%
round(df["wallmotion-score"].mean(),1)
# Out:
# 14.4

# %%
df["wallmotion-score"].fillna(
    value=round(
    df["wallmotion-score"].value_counts().mean(),
        1)
    ,inplace=True
)

# %%
df["wallmotion-index"].fillna(
    value=round(
    df["wallmotion-index"].value_counts().mean(),
        1)
    ,inplace=True
)

# %%
df.drop("mult", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#    survival  alive  age  pericardialeffusion  fractionalshortening  epss  \
# 0      11.0    0.0   71                  0.0                  0.26   9.0
# 1      19.0    0.0   72                  0.0                  0.38   6.0
#
#    lvdd  wallmotion-score  wallmotion-index  aliveat1
# 0   4.6              14.0               1.0       0.0
# 1   4.1              14.0               1.7       0.0

# %%
df["aliveat1"].value_counts()
# Out:
# 0.0    50
# 1.0    24
# 2.0     1
# Name: aliveat1, dtype: int64

# %%
df["aliveat1"].value_counts().max()
# Out:
# 50

# %%
df["aliveat1"].fillna(
    value=df["aliveat1"].value_counts().max(),
    inplace=True
)
df["aliveat1"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# survival                0
# alive                   0
# age                     0
# pericardialeffusion     0
# fractionalshortening    0
# epss                    0
# lvdd                    0
# wallmotion-score        0
# wallmotion-index        0
# aliveat1                0
# dtype: int64

# %%
for col in df.columns:
    plt.figure(figsize=(15, 5))
    sns.histplot(df[col], bins=30, kde=True) 
    plt.title(f"The Distribution of {col}", fontsize=20)
    plt.xlabel(f"{col}", fontsize=10)
    plt.show()

# %%
sns.pairplot(df);

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Matrix", fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt

for col in df.columns:
    plt.figure(figsize=(15, 10)) 
    bp = df.boxplot(col, return_type='dict')  # Boxplot zeichnen und Rückgabewert speichern
    
    # Titel und Achsenbeschriftungen
    plt.title(col, fontsize=18)
    plt.ylabel('Wert', fontsize=14)
    plt.xlabel(col, fontsize=14)
    
    # Farben anpassen
    for box in bp['boxes']:
        box.set(color='blue', linewidth=2)  # Boxfarbe und -dicke setzen
        
    for whisker in bp['whiskers']:
        whisker.set(color='red', linewidth=2)  # Farbe und Dicke der Whiskers setzen
        
    for median in bp['medians']:
        median.set(color='green', linewidth=2)  # Farbe und Dicke der Medians setzen

    plt.show()

# %%
from sklearn.neighbors import LocalOutlierFactor
lof = LocalOutlierFactor()
outliers_rows = lof.fit_predict(df)

# %%
mask = outliers_rows != -1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df=df[mask]

# %%
X = df.drop(['alive'], 1)
y = df['alive']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((91, 9), (39, 9))

# %%
accuracy = {}

# %%
##### Logistic Regression
model1 = LogisticRegression(max_iter=200)
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print(f"The Accuracy is: {accuracy_score(y_test, y_pred1)}")
accuracy[str(model1)] = accuracy_score(y_test, y_pred1)*100
# Out:
# The Accuracy is: 0.8461538461538461

# %%
##### Decision Tree Classifier
model2 = DecisionTreeClassifier(max_depth=3)
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)
print(f"The Accuracy is: {accuracy_score(y_test, y_pred2)}")
accuracy[str(model2)] = accuracy_score(y_test, y_pred2)*100
# Out:
# The Accuracy is: 0.8717948717948718

# %%
##### Random Forest Classifier 
model3 = RandomForestClassifier(max_depth=6)
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)
print(f"The Acc is: {accuracy_score(y_test, y_pred3)}")
accuracy[str(model3)] = accuracy_score(y_test, y_pred3)*100
# Out:
# The Acc is: 0.8717948717948718

# %%
#### Gradient Boosting Classifier
model4 = GradientBoostingClassifier(n_estimators=300, learning_rate=0.1)
model4.fit(X_train, y_train)
y_pred4 = model4.predict(X_test)
print(f"The Acc is: {accuracy_score(y_test, y_pred4)}")
accuracy[str(model4)] = accuracy_score(y_test, y_pred4)*100
# Out:
# The Acc is: 0.8717948717948718

# %%
accuracy
# Out:
# {'LogisticRegression(max_iter=200)': 84.61538461538461,
#  'DecisionTreeClassifier(max_depth=3)': 87.17948717948718,
#  'RandomForestClassifier(max_depth=6)': 87.17948717948718,
#  'GradientBoostingClassifier(n_estimators=300)': 87.17948717948718}

# %%
algos = list(accuracy.keys())
accu_val = list(accuracy.values())

# %%
algos
# Out:
# ['LogisticRegression(max_iter=200)',
#  'DecisionTreeClassifier(max_depth=3)',
#  'RandomForestClassifier(max_depth=6)',
#  'GradientBoostingClassifier(n_estimators=300)']

# %%
accu_val
# Out:
# [84.61538461538461, 87.17948717948718, 87.17948717948718, 87.17948717948718]

# %%
plt.figure(figsize=(15, 10))
plt.bar(algos, accu_val, width=0.4)
plt.title('Accuracy Differences', fontsize=20)
plt.xlabel('Algorithms',fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.xticks(rotation=45)
plt.show()
